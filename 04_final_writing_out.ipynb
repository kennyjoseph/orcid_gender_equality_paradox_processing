# %% [markdown]
# # Imports

# %%
import joblib
import pandas as pd

# %% [markdown]
# # Final dataframe

# %%
df = pd.read_parquet("data/final_cleaning_dataset.parquet")

# %%
df.shape, df.orcid.nunique()
# Out:
# ((13807253, 19), 6102579)

# %%
clean_role = df.role.apply(lambda x : x.strip().replace(".","").lower() if x and type(x) is str else None)
df = df.assign(clean_role=clean_role)

# %%
role_df = pd.read_parquet("data/roles.parquet")
stem_classifications = pd.read_parquet("data/stem_and_med_classifications.parquet")

# %% [markdown]
# ### Finalize merge

# %%
df.shape
# Out:
# (13807253, 20)

# %%
df = df.merge(role_df[~role_df.clean_role.duplicated()],on="clean_role",how = "left")

# %%
df.shape
# Out:
# (13807253, 21)

# %%
stem_classifications.columns = ['clean_affiliation','n_affil_tot','stem_prob','med_clf']

# %%
df_fin = pd.merge(df, stem_classifications.drop_duplicates("clean_affiliation"), on ='clean_affiliation')
df.shape, df_fin.shape
# Out:
# ((13807253, 21), (13807253, 24))

# %% [markdown]
# ## Apply Med classifier to roles

# %%
md_pattern = r'(?i)\b(?:m\.?d\.?|medical\s+doctor|doctor\s+of\s+medicine|physician|m\.?d\.?,?\s+ph\.?d\.?|ph\.?d\.?,?\s+m\.?d\.?|dr\.?\s+\(m\.?d\.?\)|m\.?b\.?b\.?s\.?|doctor\s+of\s+osteopathic\s+medicine|médico|doctor(?:a)?\s+en\s+medicina|licenciado\s+en\s+medicina|medico|médico(?:a)?|medicina|medicina\s+(?:geral)?|médecin|docteur\s+en\s+médecine|dr\.?\s+en\s+médecine|arzt|ärztin|doktor\s+der\s+medizin|dr\.?\s+med\.?|facharzt|fachärztin|dottore\s+in\s+medicina|dott\.?\s+med\.?|врач|доктор\s+медицин|медик|医生|醫生|医师|醫師|大夫|医者|医師|의사|طبيب|دكتور\s+طب|चिकित्सक|lekarz|doktor\s+medycyny|läkare|lege|læge|hekim|tıp\s+doktoru|γιατρός|ιατρός|רופא|dokter|bác\s+sĩ|แพทย์|หมอ|lékař|orvos|medic|doctor\s+în\s+medicină|lääkäri|лікар|лекар)\b'

df_fin['is_md_role'] = df_fin['role'].str.contains(md_pattern, na=False)

# %%
df_fin[df_fin['is_md_role'] ==True].role.value_counts()[:50]
# Out:
# role
# MD                                48375
# M.D.                              10849
# MBBS                              10329
# Medical Doctor                     8847
# Resident Physician                 7567
# Physician                          5754
# Doctor of Medicine                 5421
# Médico                             3519
# MD, PhD                            2869
# M.D                                2232
# Medical doctor                     2218
# Attending Physician                2207
# Medicina                           1726
# Medico                             1681
# Attending physician                1473
# Médico Cirujano                    1396
# physician                          1276
# Médico                             1225
# MD/PhD                             1118
# medical doctor                     1098
# Resident physician                 1076
# MD                                 1041
# Resident Physician                  901
# Medico Cirujano                     861
# Médico Residente                    818
# MD PhD                              801
# Doctor en Medicina                  750
# Doctor of Medicine (MD)             715
# Médico General                      694
# Medical Doctor                      685
# Dirigente Medico                    678
# MEDICO                              658
# Physician                           628
# MBBS                                566
# Doctor of Medicine                  527
# Staff Physician                     520
# M.D., Ph.D.                         513
# M.B.B.S                             494
# Graduação em Medicina               479
# attending physician                 468
# Fellow Physician                    452
# Médico Interno Residente            446
# Medico General                      443
# MEDICO CIRUJANO                     439
# Physician Assistant                 431
# Médico Veterinário                  418
# Doctor of Osteopathic Medicine      416
# Chief Physician                     406
# associate chief physician           382
# Medicina Veterinária                379
# Name: count, dtype: int64

# %%
df_fin['med_clf'] = df_fin.med_clf | df_fin.is_md_role

# %%
#pd.set_option('display.max_columns', None)
df_fin.to_csv("data/full_affiliations_data.csv", index=False)

# %%
df_fin.sample(50000).to_csv("data/full_affiliations_data_sample_50k.csv",index=False)

# %%
pd.set_option('display.max_columns', None)

df_fin.head()
# Out:
#                  orcid                                 name        type  \
# 0  0000-0003-4352-5571                   Tijana Parezanović  employment
# 1  0000-0003-4732-3571  P.V.R.; Souza PVR; Souza, PVR Souza  employment
# 2  0009-0006-9787-7571                            Rui Zhang  employment
# 3  0000-0002-2797-0571                          Rongbo Shen  employment
# 4  0000-0002-2797-0571                          Rongbo Shen  employment
#
#                               org_name  \
# 0                  Alfa BK Univerzitet
# 1  Instituto de Tecnologia em Fármacos
# 2              Northeastern University
# 3        Guangzhou National Laboratory
# 4                      Tencent (China)
#
#                                                role country  \
# 0                                    Full Professor      RS
# 1  Laboratory of Natural Products for Public Health      BR
# 2                                               NaN      CN
# 3                                 Vice investigator      CN
# 4                                        Researcher      CN
#
#                 department_name  start_year  end_year  \
# 0  Faculty of Foreign Languages      2025.0       NaN
# 1              Natural Products      2011.0       NaN
# 2          School of Metallurgy      1997.0       NaN
# 3                           NaN      2023.0       NaN
# 4               Tencent AI Lab.      2020.0    2023.0
#
#                      affiliation affiliation_type  \
# 0   faculty of foreign languages  department_name
# 1               natural products  department_name
# 2           school of metallurgy  department_name
# 3  guangzhou national laboratory         org_name
# 4                tencent ai lab.  department_name
#
#                             clean_name                                given  \
# 0                   Tijana Parezanović                   Tijana Parezanović
# 1  P.V.R.; Souza PVR; Souza, PVR Souza  P.V.R.; Souza PVR; Souza, PVR Souza
# 2                            Rui Zhang                            Rui Zhang
# 3                          Rongbo Shen                          Rongbo Shen
# 4                          Rongbo Shen                          Rongbo Shen
#
#       p(gf) to_field source_lang_translate from_field  \
# 0  0.989000      NaN                   NaN        NaN
# 1  0.581104      NaN                   NaN        NaN
# 2  0.250000      NaN                   NaN        NaN
# 3  0.250126      NaN                   NaN        NaN
# 4  0.250126      NaN                   NaN        NaN
#
#           translated_affiliation              clean_affiliation  \
# 0   faculty of foreign languages              foreign languages
# 1               natural products               natural products
# 2           school of metallurgy                     metallurgy
# 3  guangzhou national laboratory  guangzhou national laboratory
# 4                tencent ai lab.                tencent ai lab.
#
#                                          clean_role role_category  \
# 0                                    full professor          prof
# 1  laboratory of natural products for public health
# 2                                               NaN           NaN
# 3                                 vice investigator
# 4                                        researcher      research
#
#    n_affil_tot  stem_prob  med_clf  is_md_role
# 0        11154   0.000291    False       False
# 1          186   0.302680    False       False
# 2         1430   0.964940    False       False
# 3           26   0.016995    False       False
# 4            1   0.331883    False       False

# %%
df_fin.orcid.nunique()
# Out:
# 6102579

# %%
df_fin.affiliation_type.value_counts() / len(df)
# Out:
# affiliation_type
# department_name          0.909451
# org_name                 0.085213
# org_name_country_rule    0.005336
# Name: count, dtype: float64

# %% [markdown]
# # Generate Country/Year files

# %%
af = pd.read_csv("data/full_affiliations_data.csv")[['p(gf)','country','stem_prob','start_year','end_year',
             'orcid','clean_role',"role_category","clean_affiliation",'med_clf']]

# %%
af.end_year.isnull().sum(), len(af), af.end_year.isnull().sum()/ len(af)
# Out:
# (np.int64(5934276), 13807253, np.float64(0.429794108936803))

# %%
def get_role_based(role_cat, default=10):
    if role_cat == 'bachelors':
        return 4, 'BS'
    if role_cat == "masters/postgrad":
        return 2, 'MS'
    if role_cat == "postdoc":
        return 3, 'POSTDOC'
    if role_cat == "phd":
        return 5, 'PHD'
    if role_cat == 'prof' or role_cat=='head':
        return 10, 'PROF'
    return default, 'DEFAULT'


def get_by_oid(orcid_val, user_affil, out_dir, default_role):
    user_affil = user_affil.sort_values("start_year")
    total_affils = len(user_affil)
    endyears = user_affil.end_year.values.tolist()
    startyears = user_affil.start_year.values.tolist()
    fill_type = ['ENDYEAR'] * total_affils

    for affil_iter in range(total_affils):
        if pd.isnull(user_affil.iloc[affil_iter].end_year):
            year_add, role_fill = get_role_based(user_affil.iloc[affil_iter].role_category,
                                                 default=default_role)
            end_year = startyears[affil_iter] + year_add
            fill_type[affil_iter] = role_fill
            if affil_iter < (total_affils-1) and startyears[affil_iter+1] - 1 >= end_year:
                end_year = startyears[affil_iter+1] - 1
                fill_type[affil_iter] = "NEXT_START"
            endyears[affil_iter] = end_year
    user_affil['end_year'] = endyears

    out_fil = os.path.join(out_dir, str(orcid_val) + ".csv")
    all_rows = []
    for i, row in user_affil.iterrows():
        all_rows += [{"country": row['country'],
                      "oid": orcid_val,
                      'stem': row['stem_prob'],
                      'gender': row['p(gf)'],
                      'is_med': row['med_clf'],
                      "year": y
                      } for y in range(int(row['start_year']), int(row['end_year']+1))]
    pd.DataFrame(all_rows).to_csv(out_fil, index=False, header=False)
    return fill_type

# %%
import os
os.mkdir("orcid_res_10")
os.mkdir("orcid_res_5")

# %%
from multiprocessing import Pool
from tqdm import tqdm
import numpy as np
import os

# Split dataframe into chunks
n_cpus = 12
chunks = [af.iloc[idx] for idx in np.array_split(np.arange(len(af)), n_cpus)]

def process_chunk(chunk):
    for orcid_val, group in tqdm(chunk.groupby("orcid"), total=chunk.orcid.nunique()):
        get_by_oid(orcid_val, group, out_dir="orcid_res_10", default_role=10)

# Process chunks in parallel
with Pool(n_cpus) as pool:
    chunk_results = pool.map(process_chunk, chunks)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 509015/509015 [17:23<00:00, 487.92it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 508720/508720 [17:25<00:00, 486.59it/s]
#  99%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏ | 501886/507965 [17:18<00:10, 571.08it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 508414/508414 [17:24<00:00, 486.70it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 508439/508439 [17:28<00:00, 484.80it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 507928/507928 [17:30<00:00, 483.71it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 509326/509326 [17:29<00:00, 485.18it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 508695/508695 [17:27<00:00, 485.50it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 507965/507965 [17:29<00:00, 484.17it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 508292/508292 [17:28<00:00, 484.97it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 508532/508532 [17:28<00:00, 484.93it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 508622/508622 [17:27<00:00, 485.77it/s]

# %%
def process_chunk(chunk):
    for orcid_val, group in tqdm(chunk.groupby("orcid"), total=chunk.orcid.nunique()):
        get_by_oid(orcid_val, group, out_dir="orcid_res_5", default_role=5)

# Process chunks in parallel
with Pool(n_cpus) as pool:
    chunk_results = pool.map(process_chunk, chunks)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 508720/508720 [17:12<00:00, 492.64it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 509015/509015 [17:12<00:00, 493.22it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 508635/508635 [17:13<00:00, 491.91it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 508439/508439 [17:14<00:00, 491.34it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 507928/507928 [17:17<00:00, 489.69it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 508414/508414 [17:13<00:00, 492.03it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 507965/507965 [17:11<00:00, 492.35it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 509326/509326 [17:16<00:00, 491.35it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 508695/508695 [17:16<00:00, 490.55it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 508292/508292 [17:16<00:00, 490.37it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 508622/508622 [17:16<00:00, 490.57it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 508532/508532 [17:19<00:00, 489.25it/s]

# %%
# To concatenate into a single file
#find . -maxdepth 1 -type f -name '*.csv' -print0 | xargs -0 cat > ../all_default10.csv
