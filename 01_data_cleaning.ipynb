# %% [markdown]
# # Imports

# %%
import gzip
import pandas as pd
from collections import Counter
import string
from collections import defaultdict
from bs4 import BeautifulSoup
import requests
import langid
import sys
from glob import glob
import os
import pickle
# For field matching
#import field_matching
from tqdm import tqdm
STOPWORDS = set(['and','not','of','the'])
import numpy as np
import random
import re, string
from glob import glob

SUMMARY_DATA_DIR ="/data/orcid/summ_out/"

# %% [markdown]
# # Read in Processed XML files

# %%
all_summ_files = [pd.read_parquet(x) for x in tqdm(glob(f"{SUMMARY_DATA_DIR}/*_affiliations.parquet"),        
  desc="Loading parquet files")]   
print(len(all_summ_files))
d = pd.concat(all_summ_files)
# Out:
# Loading parquet files: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1100/1100 [00:27<00:00, 40.44it/s]
# 1100

# %%
d.type.value_counts()
# Out:
# type
# employment    12880514
# education      8379178
# invited         373988
# Name: count, dtype: int64

# %%
# drop invited
d = d[d.type != 'invited']

# %%
d.shape, d.orcid.nunique()
# Out:
# ((21259692, 9), 10095804)

# %%
#d.sample(25000).to_csv("sample_orcid.csv",index=False)

# %%
d.sample(3)
# Out:
#                      orcid                                 name        type  \
# 1301   0000-0002-9235-2382                      Susan R Kephart   education
# 16360  0000-0003-4008-1987  Jacielle Pauline Lima do Nascimento  employment
# 5040   0009-0003-9277-7238                           Wanpin Cai  employment
#
#                           org_name                                       role  \
# 1301      Ohio Wesleyan University                                         BA
# 16360     FRI-SABOR ALIMENTOS LTDA  ANALISTA DE CUSTOS E RENTABILIDADE Júnior
# 5040   National College of Ireland                                        NaN
#
#       country                      department_name  start_year  end_year
# 1301       US  Department of Botany & Microbiology      1970.0    1974.0
# 16360      BR                        Rentabilidade      2020.0    2020.0
# 5040       IE                                  NaN         NaN       NaN

# %%
d['affiliation'] = d.department_name
d['affiliation_type'] = 'department_name'
print(f"Not null department_name: {sum(d.affiliation.notnull())/len(d)}")
# Out:
# Not null department_name: 0.7367723859781223

# %%
print(f"""Of null department_name, percent not-null org: 
{len(d[d.department_name.isnull() & d.org_name.notnull()])/len(d[d.department_name.isnull()])}
""")
# Out:
# Of null department_name, percent not-null org:
# 1.0

# %%
d.loc[d.department_name.isnull(),"affiliation"] = d.loc[d.department_name.isnull(),"org_name"] 
d.loc[d.department_name.isnull(),"affiliation_type"] = 'org_name'

# %% [markdown]
# ## If the "department_name" matches an entry on a list of "departments" in that country (see list in paper), then don't feed the department name to the STEM classifier

# %%
regions_by_country = {
    "CO": [
        "Amazonas", "Antioquia", "Arauca", "Atlántico", "Bolívar", "Boyacá",
        "Caldas", "Caquetá", "Casanare", "Cauca", "Cesar", "Chocó", "Córdoba",
        "Cundinamarca", "Distrito Capital", "Guainía", "Guaviare", "Huila",
        "La Guajira", "Magdalena", "Meta", "Nariño", "Norte de Santander",
        "Putumayo", "Quindío", "Risaralda", "San Andrés y Providencia",
        "Santander", "Sucre", "Tolima", "Valle del Cauca", "Vaupés", "Vichada"
    ],
    "PE": [
        "Amazonas", "Ancash", "Apurímac", "Arequipa", "Ayacucho", "Cajamarca",
        "Callao", "Cusco", "Huancavelica", "Huánuco", "Ica", "Junín",
        "La Libertad", "Lambayeque", "Lima", "Loreto", "Madre de Dios",
        "Moquegua", "Pasco", "Piura", "Puno", "San Martín", "Tacna",
        "Tumbes", "Ucayali"
    ],
    "SV": [
        "Ahuachapán", "Cabañas", "Chalatenango", "Cuscatlán", "La Libertad",
        "La Paz", "La Unión", "Morazán", "San Miguel", "San Salvador",
        "San Vicente", "Santa Ana", "Sonsonate", "Usulután"
    ],
    "BO": [
        "Chuquisaca", "Cochabamba", "El Beni", "La Paz", "Oruro", "Pando",
        "Potosí", "Santa Cruz", "Tarija"
    ],
    "UY": [
        "Artigas", "Canelones", "Cerro Largo", "Colonia", "Durazno",
        "Flores", "Florida", "Lavalleja", "Maldonado", "Montevideo",
        "Paysandú", "Río Negro", "Rivera", "Rocha", "Salto", "San José",
        "Soriano", "Tacuarembó", "Treinta y Tres"
    ],
    "PY": [
        "Alto Paraguay", "Alto Paraná", "Amambay", "Asunción", "Boquerón",
        "Caaguazú", "Caazapá", "Canindeyú", "Central", "Concepción",
        "Cordillera", "Guairá", "Itapúa", "Misiones", "Ñeembucú",
        "Paraguarí", "Presidente Hayes", "San Pedro"
    ]
}

# %%
for k, v in regions_by_country.items():
    locs = [x.lower() for x in v]
    country_df = d[d.country == k]
    mask = ((d.country == k) & (d.department_name.str.lower().isin(locs)) &
            (~d.org_name.str.lower().isin(locs))
           )
    print(f"""Country: {k}
                N in Country: {len(country_df)}
                % department is location:
                    {mask.sum()/len(country_df)}
            """)
    
    d.loc[mask,"affiliation"] = d.loc[mask,"org_name"]
    d.loc[mask,"affiliation_type"] = "org_name_country_rule"
# Out:
# Country: CO
#                 N in Country: 514929
#                 % department is location:
#                     0.21280797935249327
#
# Country: PE
#                 N in Country: 616314
#                 % department is location:
#                     0.3553545757519706
#
# Country: SV
#                 N in Country: 8975
#                 % department is location:
#                     0.16044568245125349
#
# Country: BO
#                 N in Country: 24669
#                 % department is location:
#                     0.17649681786857999
#
# Country: UY
#                 N in Country: 17256
#                 % department is location:
#                     0.07452480296708391
#
# Country: PY
#                 N in Country: 21534
#                 % department is location:
#                     0.06427045602303334

# %% [markdown]
# ## Do a little cleaning

# %%
d['affiliation'] = d.affiliation.str.replace("\t"," ").str.strip()

# %%
# For non-English, 2 characters could reasonably be a field! But only one ... probably not

print((d.affiliation.str.len() < 2).sum())
d = d[d.affiliation.str.len()>=2]
# Out:
# 3278

# %%
print(d.affiliation.isin(['n/a','none','na']).sum())
d = d[~d.affiliation.isin(['n/a','none','na'])]
# Out:
# 533

# %% [markdown]
# # Set Dates and Drop Null Dates

# %%
print(f"Proportion no start/end year: {len(d[d.start_year.isnull() & d.end_year.isnull()])/len(d)}")
# Out:
# Proportion no start/end year: 0.1972161963082123

# %%
d = d[d.start_year.notnull() | d.end_year.notnull()]

# %%
d.affiliation_type.value_counts() / len(d)
# Out:
# affiliation_type
# department_name          0.795450
# org_name                 0.187196
# org_name_country_rule    0.017354
# Name: count, dtype: float64

# %%
end_no_start = (d.start_year.isnull() &  ~d.end_year.isnull())
print(f"%age with end year but no start year: {end_no_start.sum()/len(d)}")
# Out:
# %age with end year but no start year: 0.02411814149855862

# %%
d.loc[end_no_start,"start_year"] = d.loc[end_no_start].end_year
d.loc[end_no_start,"end_year"] = np.nan

# %%
d.shape, d.orcid.nunique()
# Out:
# ((17063877, 11), 7110339)

# %%
d.end_year.isnull().sum(), len(d), d.end_year.isnull().sum()/ len(d)
# Out:
# (np.int64(7256909), 17063877, np.float64(0.42527902656588534))

# %% [markdown]
# # Translation

# %%
tr = dict((ord(x), None) for x in string.punctuation if x != " " and x != "-")

def lookup(myjson, k):
  # return myjson[k]
  if '.' in k:
    # jpath path
    ks = k.split('.')
    v = myjson
    for k in ks: 
        if not v:
            return ""
        v = v.get(k,{})
    return v or ""
  return myjson.get(k,"")


def get_terms(text, term_set =None):
    spl = re.split("[ /+,]",text.lower())
    t = set([x.translate(tr) for x in spl])
    if term_set:
        return t & term_set
    return t

# %%
#NSF Fields
import requests 
from collections import defaultdict,Counter
from bs4 import BeautifulSoup
tab = requests.get("https://wayback.archive-it.org/5902/20231215174930/https://www.nsf.gov/statistics/2017/nsf17306/datatables/tab-13.htm")
s = BeautifulSoup(tab.text)
tab = s.find("table",{"id" : "data-table"})

def get_text_indent(row):
    text = row.text.replace(", general","").replace(", other","").lower().strip()
    indent = int(row['class'][0].replace("indent_",""))
    return text, indent

nsf_field_hierarchy = defaultdict(list)
nsf_terms = set()
rows = tab.find_all("th", {"scope" : "row"})

# stupid but it works
i = 1
while i < len(rows):
    # get my info
    curr_text, curr_indent  = get_text_indent(rows[i])
    # make sure this isn't already in the tree
    if curr_text not in nsf_terms:
        nsf_terms.add(curr_text)
        for j in reversed(range(i)):
            prev_text, prev_indent = get_text_indent(rows[j])
            if curr_indent - prev_indent == 1:
                nsf_field_hierarchy[prev_text].append(curr_text)
                break
    #else:
        #print rows[i].text, curr_text, ' already in tree'
    i += 1

nsf_termlist = Counter()
for x in nsf_terms:
    nsf_termlist.update([x for x in get_terms(x) if x not in STOPWORDS])
nsf_termlist = set(nsf_termlist.keys())

# %%
# Wikipedia Fields
#https://en.wikipedia.org/wiki/Outline_of_academic_disciplines
def get_text_indent_wiki(row):
    indent = -1
    if row.startswith("==="):
        indent = 1
    elif row.startswith("=="):
        indent = 0
    elif row.startswith("'''"):
        indent = 2
    elif row.startswith("***"):
        indent = 5
    elif row.startswith("**"):
        indent = 4
    elif row.startswith("*"):
        indent = 3
    else:
        pass
        #print "NOPE", row
    text = row.replace("*","").replace("=","").lower().strip()
    
    text = text.replace("'''","")

    text = re.sub("(#|\|)[a-z A-Z\(\)]+\]\]","",text)
    text = text.replace("[[","").replace("]]","").strip()
    if text.rfind("(outline") != -1:
        text = text[:text.rfind("(outline")]
    return text.strip(), indent

wiki_field_hierarchy = defaultdict(list)
rows = [get_text_indent_wiki(x) for x in open("data/wiki_page.txt").readlines()]
rows = [x for x in rows if x[1] != -1]
wiki_terms = set()

# stupid but it works
i = 1
while i < len(rows):
    # get my info
    curr_text, curr_indent  = rows[i]
    # make sure this isn't already in the tree
    if curr_text not in wiki_terms:
        wiki_terms.add(curr_text)
        for j in reversed(range(i)):
            prev_text, prev_indent = rows[j]
            if curr_indent - prev_indent > 0:
                wiki_field_hierarchy[prev_text].append(curr_text)
                break
    i += 1
    
wiki_termlist = Counter()
for x in wiki_terms:
    wiki_termlist.update([x for x in get_terms(x) if x not in STOPWORDS])
wiki_termlist = set(wiki_termlist.keys())


for term in wiki_terms:
    if term not in wiki_field_hierarchy:
        wiki_field_hierarchy[term] = []
        
        
# Archaeology is a social science discipline - https://en.wikipedia.org/wiki/Archaeology
# So is communications
wiki_field_hierarchy['social sciences'].append("archaelogy")
wiki_terms.add("archaeology")
wiki_field_hierarchy['social sciences'].append("communications")
wiki_terms.add("communications")

# if Music history is a subset of Music, art history should be a subset of art
wiki_field_hierarchy["visual arts"].append("art history")
wiki_terms.add("art history")

# Classics == classical literature
wiki_field_hierarchy["history of literature"].append("classics")
wiki_field_hierarchy["history of literature"].append("classical literature")
wiki_terms.add("classics")
wiki_terms.add("classical literature")

# If English lit is under language and arts, so is spanish
wiki_field_hierarchy["languages and literature"].append("spanish literature")
wiki_terms.add("spanish literature")

# %%
remove_list = {'a',''
  'as',
 'early',
 'or',
 'tv',
 'us',
'than',
'chemistrya',
'non-se',
'field',
'list','2017'}
nsf_termlist = nsf_termlist - remove_list
wiki_termlist = wiki_termlist - remove_list

# %%
# Bring back in cleaned version and count number of terms in each individual's department
manual_termlist = {x.split("\t")[0] for x in open("manual_keywords.tsv")}

# %%
# Write out the fields that we need to translate to English
non_eng_affl = d[~d.country.isin(["US","UK", "GB"])].affiliation.unique()
print(len(non_eng_affl))
# Out:
# 3091209

# %%
nsf_termlist = {x for x in nsf_termlist if len(x) > 3}
wiki_termlist = {x for x in wiki_termlist if len(x) > 3}

# %%
# with open("all_terms.txt","w") as af:
#     for term in nsf_termlist | wiki_termlist | manual_termlist:
#         af.write(term + "\n")

# %%
to_translate = set()
for i,x in enumerate(non_eng_affl):
    if i % 50000 == 0:
        print(i)
    if x and type(x) is str: 
        terms = get_terms(x)
        if (len(terms & nsf_termlist) or 
            len(terms & wiki_termlist) or 
            len(terms & manual_termlist) or 
            langid.classify(x)[0] == 'en'):
                continue
        to_translate.add(x.lower())
# Out:
# 0
# 150000

# %% [markdown]
# ## Do google translate

# %%
final_translation = pd.read_parquet("data/final_final_translation_2025.parquet")

# %%
add_trans = pd.DataFrame([('enfermagem', '', 'nursing'),
('odontologia', '', 'dentistry'),
('geografia', '', 'geography'),
('engenharia civil', '', 'civil engineering'),
('direito', '', 'law'),
('saúde', '', 'health'),
('educação física', '', 'physical education'),
('filosofia e ciências sociais', '', 'philosophy and social sciences'),
('comunicação social', '', 'social communication'),
('cse', '', 'computer science and engineering'),
('ece', '', 'electrical and computer engineering'),
('eee', '', 'electrical and electronics engineering'),
('serviço social', '', 'social services'),
('it', '', 'information technology'),
('lime', '', ''),
('bme','','biomedical engineering'),
('cfe', '','certified fraud examiner'),
('cs','','computer science'),
('csis', '','computer science and information systems'),
('eecs','','electrical engineering and computer science'),
('hse','','health sciences and environment'),
('ict','','information and communication technology'),
('mba','','masters in business administration'),
('mbbs','','bachelor in medicine and surgery'),
('mca','','masters of computing applications'),
('me','','masters in engineering'),
('mis','','masters in information systems'),
("departamento de letras",'','law'),
("faculdade de letras",'','law'),
("letras",'','law'),
("instituto de letras",'','law'),
("lettres",'','law'),
("facultatea de litere",'','law'),
("département lettres",'','law'),
("departmento de letras",'','law'),
("de letras",'','law'),
("letteren",'','law'),
("lletres",'','law'),
("departamentul de litere",'','law'),
("depatarmento de letras",'','law'),
("de  letras",'','law'),
("institulo de letras",'','law'),
("dipartimento di lettere",'','law'),
("escola de letras",'','law'),
("departamento de letas",'','law'),
("facultat de letras",'','law'),
("(instituto de letras)",'','law'),
("instuto de letras",'','law'),
("facultá di lettere",'','law'),
("faaculdade de letras",'','law'),
("la facultad de letras",'','law'),
("facultade de letras",'','law'),
("facolta di lettere",'','law'),
("il instituto de letras",'','law'),
("facultad de filosofìa y letras",'','law'),
("instituto de letras / 文学部",'','law'),
("faculdade das letras",'','law'),
("faculte des lettre",'','law'),
("instituto de  letras",'','law'),
("deparatmento de letras",'','law'),
("depto. de letras",'','law'),
("departamendo de letras",'','law'),
("facultate de litere",'','law'),
("facoltá di lettere",'','law'),
("u.f.r. de lettres",'','law'),
("faceuldade de letras",'','law'),
("departamento de letras.",'','law'),
("departamento  de letras",'','law'),
("faculadade de letras",'','law'),
("faculdade de  letras",'','law'),
("facultad de lletres",'','law'),
("departamento de letraas",'','law'),
("faculade de letras",'','law'),
("faculdade de   letras",'','law'),
("fscultad de letras",'','law'),
("institut de lettres",'','law') ])
add_trans.columns = ['from_field','source_lang_translate','to_field']

# %%
final_translation  = pd.concat([final_translation[~final_translation.from_field.isin(add_trans.from_field.values)],
          add_trans])

# %%
already_translated = final_translation.from_field.tolist()
                                
print(len(set(to_translate)), len(set(already_translated)), 
      len(set(to_translate) - set(already_translated)))
# Out:
# 0 1343292 0

# %%
to_translate = list(set(to_translate) - set(already_translated))

# %%
additional_translations_from_further_analysis = pd.read_csv("../orcid_gender_equality_paradox_processing/additional_translations.csv").x.values.tolist()

# %%
to_translate += additional_translations_from_further_analysis

# %%
len(to_translate)
# Out:
# 447

# %%
from google.oauth2 import service_account
from google.cloud import translate_v2 as translate

credentials = service_account.Credentials.from_service_account_file(
    '../orcid/andrei-480903-13049259f1c6.json'
)
translate_client = translate.Client(credentials=credentials)

# %%
sum(map(len, to_translate))
# Out:
# 12306

# %%
import math 
import time
# Translate the list
batch_size = 100
translations = []
num_batches = math.ceil(len(to_translate) / batch_size)

for i in tqdm(range(0, len(to_translate), batch_size), 
              total=num_batches,
              desc="Translating batches"):
    batch = to_translate[i:i + batch_size]
    results = translate_client.translate(batch, target_language='en')
    translations.extend(results)
    time.sleep(5)
# Out:
# Translating batches: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:27<00:00,  5.43s/it]

# %%
len(translations)
# Out:
# 447

# %%
pd.DataFrame(translations).to_parquet("data/translated_fieldnames_2026_postprocessing.parquet")

# %%
pd.DataFrame(translations).sample(10)
# Out:
#                                         translatedText detectedSourceLanguage  \
# 180                       Faculty of Civil Engineering                     es
# 141                        higher school of journalism                  pt-PT
# 317                                           physique                     en
# 405  central outreach service and activities in the...                     es
# 5                                       agrotechnology                     id
# 66                                  central department                     es
# 158                     graduate school of social work                     es
# 271                               Hôtel-Dieu de France                     fr
# 68                        civil engineering department                     pt
# 76                                software development                     es
#
#                                                  input
# 180                       facultad de ingeniería civil
# 141                      escola superior de jornalismo
# 317                                           physique
# 405  servicio central de extensión y actividades en...
# 5                                        agroteknologi
# 66                                departamento central
# 158                 escuela graduada de trabajo social
# 271                               hôtel-dieu de france
# 68                    departamento de engenharia civil
# 76                              desarrollo de software

# %% [markdown]
# ## Combine, create final translated dataset

# %%
new_translations = pd.DataFrame(translations)
new_translations.columns = ['to_field','source_lang_translate','from_field']

# %%
pd.concat([final_translation,new_translations]).to_parquet("data/final_final_translation_2026_postprocessing.parquet")

# %% [markdown]
# # Gender inference

# %% [markdown]
# ## Clean names

# %%
# TAKEN FROM https://github.com/cthoyt/orcid_downloader/blob/main/src/orcid_downloader/name_utils.py!!!!

punc_trans = str.maketrans('', '', string.punctuation)
def clean_name(name: str) -> str:
    """Clean a name string.

    :param name: A full name
    :return: A cleaned full name, e.g., stripped of titles and suffixes
    """
    # strip titles like Dr. and DR. from beginning of all names/aliases
    # strip post-titles Francess Dufie Azumah (DR.)
    lower = name.lower()
    if lower.startswith("professor "):
        name = name[len("professor ") :].strip()
    if lower.startswith("prof."):
        name = name[len("prof.") :].strip()
    if lower.startswith("dr.-ing."):
        name = name[len("dr.-ing.") :]
    if lower.startswith("dr "):
        name = name[len("dr ") :]
    if lower.startswith("dr."):
        name = name[len("dr.") :].strip()

    for suffix in [
        "(dr)",
        "(dr.)",
        ", m.d.",
        ", phd",
        ", md",
        ", mph",
        ", ph.d.",
        ", ms",
    ]:
        if lower.endswith(suffix):
            name = name.removesuffix(suffix).strip()

    name = name.replace('"', "")
    name = name.strip("/")
    name = name.strip("\\")

    # Fix lazily written in all caps or lower
    if name == name.lower() or name == name.upper():
        name = name.title()

    return name

# %%
d['clean_name'] = d.name.apply(clean_name)
d['clean_name'] = d.clean_name.str.replace(                                              
  r"^[^\w\s]+|[^\w\s]+$",                                                              
  "",                                                                                  
  regex=True,                                                                          
  flags=re.UNICODE                                                                     
)                                                                                        
       
d['clean_name'] = d.clean_name.str.replace("^(([a-z][a-z]?[.]?)|(prof[.]?)) ", "", 
                               regex=True, 
                               flags=re.IGNORECASE)
d['clean_name'] = d.clean_name.str.replace("^(([a-z][a-z]?[.]?)|(prof[.]?)) ", "", 
                               regex=True, 
                               flags=re.IGNORECASE)

# %%
# Find rows with only spaces/punctuation
mask = ~d['clean_name'].str.contains(r'\w', na=True, flags=re.UNICODE)

# %%
# Filter the dataframe
print(f"Names with only spaces or punctuation: {mask.sum()}")
d = d[~mask]
# Out:
# Names with only spaces or punctuation: 912

# %%
# only one alpha character
mask = d.clean_name.str.match(r'^[a-zA-Z]$', na=False)
print(f"Names with only one alpha character: {mask.sum()}")
d = d[~mask]
# Out:
# Names with only one alpha character: 735

# %%
all_names = d.clean_name.unique().tolist()

# %%
len(all_names)
# Out:
# 6230821

# %% [markdown]
# ## Run NomQuam

# %%
import nomquamgender as nqg
model = nqg.NBGC()
n = model.annotate(all_names, as_df=True)

# %%
# Explore missing and write out for other tool
missing = n.loc[n['p(gf)'].isna()]
missing.to_csv("missing_names.csv",index=False)
missing['used'].value_counts()[:10]
# Out:
# used
# d.      444
# m.      418
# s.      368
# m       332
# dra.    287
# a.      278
# mst.    228
# c.      224
# moh.    191
# dr.)    187
# Name: count, dtype: int64

# %%
# How many are missing
n.loc[n['p(gf)'].isna()].shape
# Out:
# (541217, 5)

# %%
n.loc[n['p(gf)'].isna()].sample(10)
# Out:
#                         given         used  sources  counts  p(gf)
# 4780734     Binaram Bhandari       binaram        0       0    NaN
# 5458089    Abdalfattah Okasha  abdalfattah        0       0    NaN
# 3266259        Yadeta Chemeda       yadeta        0       0    NaN
# 155674   Zulfiquer Ahmed Amin    zulfiquer        0       0    NaN
# 5668288          Hayany Madca       hayany        0       0    NaN
# 830236   Nalge Swapnil Sunil         nalge        0       0    NaN
# 185940         Mahadee Hassan      mahadee        0       0    NaN
# 5154975               J.T. Yi         j.t.        0       0    NaN
# 5958854             V.Manjari    v.manjari        0       0    NaN
# 5250828          Vedapradha R   vedapradha        0       0    NaN

# %%
# Look at per-country missing names
m = pd.merge(n,d[['clean_name','country']], 
             left_on="given",
             right_on="clean_name",how="left")
m['has_val'] = m['p(gf)'].isna()

gb = m.groupby(['country','has_val']).size().reset_index()
gb.columns = ['country','is_null','cnt']
gb.to_csv("country_to_missing_names.csv",index=False)

# %% [markdown]
# ## Run Namsor on missing names

# %%
missing_names = n.loc[n['p(gf)'].isna()].given.values
already_done = pd.read_parquet("data/namsor_gender_outputs.parquet")
still_missing = list(set(missing_names)- set(already_done.name))

# %%
len(missing_names),len(missing_names)/len(n)
# Out:
# (541217, 0.08686126595516064)

# %%
len(still_missing)
# Out:
# 0

# %%
import requests
from tqdm import tqdm

API_KEY = "YOUR_API_KEY"
BASE_URL = "https://v2.namsor.com/NamSorAPIv2/api2/json"

headers = {
    "X-API-KEY":API_KEY,
    "Accept": "application/json",
    "Content-Type": "application/json"
}


def get_gender_full_batch_safe(full_names_list, batch_size=100):
    """Process full names in batches with error handling"""
    all_results = []
    
    for i in tqdm(range(0, len(full_names_list), batch_size)):
        batch = full_names_list[i:i+batch_size]
        names = [{"name": name} for name in batch]
        
        url = f"{BASE_URL}/genderFullBatch"
        payload = {"personalNames": names}
        
        try:
            response = requests.post(url, json=payload, headers=headers)
            response.raise_for_status()
            results = response.json()
            all_results.extend(results['personalNames'])
        except requests.exceptions.RequestException as e:
            print(f"Error processing batch {i}: {e}")
            # Add None values for failed batch
            all_results.extend([None] * len(batch))
    
    return all_results

# Usage
results = get_gender_full_batch_safe(still_missing)
# Out:
# 0it [00:00, ?it/s]

# %%
pd.concat([pd.DataFrame(results),already_done]).to_parquet("data/namsor_gender_outputs.parquet")

# %%
namsor_results = pd.concat([pd.DataFrame(results),already_done])
namsor_results.head()
# Out:
#    script                                    id                 name  \
# 0   LATIN  44361fb6-c70d-4501-b4c6-2991fc2eabcf  ehriban Kaşım Kaşım
# 1   LATIN  c2a32394-be88-4977-917e-7510a6cf05c7        leshko Sergei
# 2   LATIN  db5851d7-4adb-43fd-82eb-58a65ac1aebc               Langel
# 3   LATIN  e7e8f2c2-894f-4ebc-a33f-1c1fae4b9c48       ubomíra Kmeťov
# 4  LATIN+  123629f0-4eaa-4ce2-9b3c-2889ff245038    nci̇ Baysal İlhan
#
#   likelyGender  genderScale     score  probabilityCalibrated
# 0       female     0.086046  0.538143               0.543023
# 1         male    -0.274907  2.212001               0.637453
# 2         male    -0.777341  8.986101               0.888670
# 3         male    -0.294009  2.336700               0.647004
# 4         male    -0.647738  8.045993               0.823869

# %% [markdown]
# ## Construct final names dataset

# %%
# Match Namsor probabilities to NomQuam
def gen_miss(x):
    if x['likelyGender'] == 'female':
        return x['probabilityCalibrated']
    return 1-x['probabilityCalibrated']
namsor_results['p(gf)'] = namsor_results.apply(gen_miss,axis=1)

# %%
namsor_results['given'] = namsor_results.name

# %%
final_names = pd.concat([n[['given','p(gf)']][~n['p(gf)'].isna()],
           namsor_results[['given','p(gf)']]],
          axis=0)

# %%
final_names.shape, len(all_names), final_names[~final_names.given.duplicated()].shape
# Out:
# ((6326902, 2), 6230821, (6326902, 2))

# %%
d.shape, d.merge(final_names, left_on="clean_name", right_on="given", how ='left').shape
# Out:
# ((17062230, 12), (17062230, 14))

# %%
d = d.merge(final_names, left_on="clean_name", right_on="given", how ='left')

# %%
d[d['p(gf)'].isnull()].shape
# Out:
# (0, 14)

# %% [markdown]
# # Complete translation

# %%
translated = pd.read_parquet("data/final_final_translation_2026_postprocessing.parquet")
translated.from_field = translated.from_field.str.lower()
translated.to_field = translated.to_field.str.lower()
translated = translated[translated.from_field != translated.to_field]
translated.drop_duplicates("from_field",inplace=True)

# %%
d['affiliation'] = d['affiliation'].str.lower()

# %%
d = pd.merge(d, translated,left_on="affiliation",right_on="from_field",how="left")
d['translated_affiliation'] = d.apply(lambda x : x['affiliation'] if pd.isnull(x['to_field']) else x['to_field'],axis=1)
d.shape
# Out:
# (17062230, 18)

# %%
pd.set_option('display.max_colwidth', None)

# %%
def clean_fieldnames(name):
    if not name:
        return None
    name = name.lower().strip()
    # Excel error values
    if '#value!' in name:
        return None
    # HTML entities
    name = name.replace("&quot;", "")
    # Doubled/escaped quotes like ""electric traction""
    name = re.sub(r'"+', '', name)
    # Leading numeric codes like "100008 - experimental medicine" or "100008-"
    name = re.sub(r'^\d+\s*[-–]\s*', '', name)
    name = name.replace("department of", "")
    name = name.replace("dept of", "")
    name = name.replace("faculty of", "")
    name = name.replace("school of", "")
    name = name.replace("college of", "")
    name = name.replace("institute for", "")
    name = name.replace("institute of", "")
    name = name.replace("the ", "")
    name = name.replace("  ", " ")
    name = name.replace("\t", " ").replace("\n", " ")
    name = name.replace("(", "").replace(")", "")
    name = name.strip()
    return name if name else None

d = d.assign(clean_affiliation=d.translated_affiliation.apply(clean_fieldnames))

# %%
# Drop affiliations that are None/empty or consist only of digits/whitespace
before = len(d)
d = d[d.clean_affiliation.notna()]
d = d[~d.clean_affiliation.str.fullmatch(r'[\d\s]+')]
print(f"Dropped {before - len(d)} rows with empty or numbers-only clean_affiliation")
# Out:
# Dropped 3949 rows with empty or numbers-only clean_affiliation

# %% [markdown]
# # Drop people with excessive role counts

# %%
# How many affiliations per person
affiliations_per_person = d.groupby("orcid").size()

# %%
affiliations_per_person.shape
# Out:
# (7107389,)

# %%
affl_percentage_cum = (affiliations_per_person.value_counts()/float(len(affiliations_per_person))).cumsum()

# %%
# Cumsum of affiliations per person - we can toss ppl with > 12 affiliations and lose only .05% of the data
affl_percentage_cum.head(15)

#what are these 2 affiliations?
# Out:
# 1     0.503463
# 2     0.690992
# 3     0.796904
# 4     0.869498
# 5     0.914778
# 6     0.944296
# 7     0.963462
# 8     0.975934
# 9     0.983945
# 10    0.989068
# 11    0.992405
# 12    0.994658
# 13    0.996148
# 14    0.997173
# 15    0.997884
# Name: count, dtype: float64

# %%
# Remove ppl with > 12 affiliations

d = d[d.orcid.isin(affiliations_per_person[affiliations_per_person < 13].index.values)]
print(d.shape)
# How many ppl. do we have a this point?
d.orcid.nunique()
# Out:
# (16426257, 19)
# 7069422

# %%
d.country.nunique()
# Out:
# 250

# %%
d.shape
# Out:
# (16426257, 19)

# %%
d.orcid.nunique()
# Out:
# 7069422

# %% [markdown]
# # Checking field translations and non-academic fields per country

# %% [markdown]
# ## Exclude things that are just university names or other clear roles/organizations with no attachment to fields

# %%
mask = ((d["clean_affiliation"].str.contains("universi|student|college", na=False)) & 
        (~d["clean_affiliation"].isin(["school", "postgraduate", "high school"]))
       )

# %%
d[mask].clean_affiliation.value_counts()[:25]
# Out:
# clean_affiliation
# college                                    74612
# césar vallejo university                   27938
# university                                 15430
# peruvian university of applied sciences    13658
# national university of san marcos           8986
# university of barcelona                     8743
# complutense university of madrid            8548
# cesar vallejo university                    7404
# national university of colombia             7001
# university of granada                       6391
# technological university of peru            6002
# university of sao paulo                     5986
# university of antioquia                     5294
# south scientific university                 5146
# autonomous university of barcelona          4992
# student                                     4900
# university of valencia                      4701
# universidad continental                     4680
# education university                        4606
# open and distance national university       4510
# sevilla university                          4347
# zhejiang university                         4212
# autonomous university of madrid             4048
# university of melbourne                     3985
# university of copenhagen                    3888
# Name: count, dtype: int64

# %%
mask.sum()
# Out:
# np.int64(2380757)

# %%
d = d[~mask]

# %%
d.shape
# Out:
# (14045500, 19)

# %%
c = d.groupby(['country','clean_affiliation']).size().reset_index()
c.columns = ['country','clean_affiliation','count_val']
c[c.count_val> 5].to_csv("data/robustness_field_cnt.csv",index=False)

# %% [markdown]
# ## Run robustness scripts to identify additional translations and non-academic fields

# %%
non_academic_fields = pd.read_csv("data/classified_nonacademic.csv")

# %%
non_academic_fields
# Out:
#                      cmd  category
# 0                managua  location
# 1                 pillow     other
# 2                   lion     other
# 3              chontales  location
# 4              matagalpa  location
# ..                   ...       ...
# 855               qutech   acronym
# 856                  fmg   acronym
# 857  academic staff unit     other
# 858              wetsuit     other
# 859                 lime     other
#
# [860 rows x 2 columns]

# %%
mask = d.clean_affiliation.isin(non_academic_fields.cmd)
mask.sum()
# Out:
# np.int64(238247)

# %%
d = d[~mask]

# %%
## checking 
c = d.groupby(['country','clean_affiliation']).size().reset_index()
c.columns = ['country','clean_affiliation','count_val']
c[c.count_val> 5].to_csv("data/post_robustness_field_cnt.csv",index=False)

# %%
d.shape
# Out:
# (13807253, 19)

# %%
d.clean_affiliation.nunique()
# Out:
# 2477684

# %%
d.orcid.nunique()
# Out:
# 6102579

# %%
d.to_parquet("data/final_cleaning_dataset.parquet")

# %%
mg = pd.merge(d[d.affiliation.str.contains("letters")].country.value_counts().reset_index(),
         d.country.value_counts().reset_index(),
         on="country")
mg['perc'] =mg.count_x/mg.count_y
mg.head(10)
# Out:
#   country  count_x  count_y      perc
# 0      US      869  2058440  0.000422
# 1      JP      649   213738  0.003036
# 2      BR      494  1321624  0.000374
# 3      RO      403    47518  0.008481
# 4      TR      202   369818  0.000546
# 5      PH      166    76000  0.002184
# 6      ID      143   249024  0.000574
# 7      PL      127   167151  0.000760
# 8      PT      127   224403  0.000566
# 9      IT      104   300206  0.000346
